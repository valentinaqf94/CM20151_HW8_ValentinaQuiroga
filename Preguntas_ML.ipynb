# %% [markdown]
# 1. Qué otros datos pueden ayudarlo a mejorar su predicción?
# 2. Cuál día de la semana presenta el número mayor de órdenes?
# 3. Cuál día de la semana presenta el menor número de órdenes?

# %% [markdown]
# 1. Tal vez conocer para qué sirve conteo_indices puede ayudar en esto, pero como no conocí nunca su labor real,
# opté por que el mismo programa entendiera (sin que yo lo hiciera) la labor que éste dato cumple en la predicción. No sé
# si esto también entre en "datos" pero saber qué constantes de red neuronal usar puede que sea una gran fuente
# de error en mi modelo pues aun no entiendo bien cómo se eligen, por lo que las dispuse a ensayo y error, partiendo
# de un valor aproximado. Tal vez tener mayor volumen de datos de training puede ayudar, y aunque haría al programa más
# ineficiente, su confiabilidad crecería.
#
# 2. El día que presenta mayor numero de órdenes es el sábado y lo calculé directamente en Excel.
#
# 3. El día de menor número de órdenes es el lunes.
#
# Es importante anotar que dichos resultados no dependen del output, su tendencia se preserva.
#
# Este modelo es un ensamble, usando PCA para preprocesar los datos antes de que entren al modelo predictivo definitivo y luego usando una red neuronal.
#
# Para correr el programa:
#     python process.py process
#     python process.py predict
#
# Toda la biblografía de red neuronal y preprocesamiento de datos que usé está acá:
# https://d396qusza40orc.cloudfront.net/neuralnets/lecture_slides/lec3.pdf
# https://d396qusza40orc.cloudfront.net/neuralnets/lecture_slides/lec9.pdf
# http://ufldl.stanford.edu/wiki/index.php/UFLDL_Tutorial
# http://ufldl.stanford.edu/wiki/index.php/Whitening
# http://ufldl.stanford.edu/wiki/index.php/Neural_Networks
# http://en.wikipedia.org/wiki/Dimensionality_reduction
# http://stackoverflow.com/questions/9590114/importance-of-pca-or-svd-in-machine-learning
# http://stackoverflow.com/questions/9590114/importance-of-pca-or-svd-in-machine-learning
# http://www.iro.umontreal.ca/~memisevr/code.html
# http://en.wikipedia.org/wiki/Kullback%E2%80%93Leibler_divergence
# http://en.wikipedia.org/wiki/Delta_rule
